# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshijadhav-08/python-visualization-assignment/blob/main/18_Op.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-347d594e-ec17-4a30-97a9-86d540bb8934" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-347d594e-ec17-4a30-97a9-86d540bb8934">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath = './insurance.csv'
ds = pd.read_csv(filepath,encoding="latin1")
ds.head(10)
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59
# 7   37  female  27.7         3     no  northwest   7281.51
# 8   37    male  29.8         2     no  northeast   6406.41
# 9   60  female  25.8         0     no  northwest  28923.14

# %%
ds.tail()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
ds.shape
# Out:
# (1338, 7)

# %%
ds.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
ds.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
ds.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
ds.duplicated().sum()
# Out:
# np.int64(1)

# %%
ds.drop_duplicates()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1337 rows x 7 columns]

# %%
ds.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
ds["age"].hist()
# Out:
# <Axes: >

# %%
sns.countplot(x="sex", data=ds)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.heatmap(ds.select_dtypes(include="number").corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
X = ds.drop("expenses", axis=1)
X.head()
# Out:
#    age     sex   bmi  children smoker     region
# 0   19  female  27.9         0    yes  southwest
# 1   18    male  33.8         1     no  southeast
# 2   28    male  33.0         3     no  southeast
# 3   33    male  22.7         0     no  northwest
# 4   32    male  28.9         0     no  northwest

# %%
y = ds["expenses"]
y.head()
# Out:
# 0    16884.92
# 1     1725.55
# 2     4449.46
# 3    21984.47
# 4     3866.86
# Name: expenses, dtype: float64

# %%
ds = pd.get_dummies(ds, columns=["sex", "smoker", "region"], drop_first=True)

ds.head()
# Out:
#    age   bmi  children  expenses  sex_male  smoker_yes  region_northwest  \
# 0   19  27.9         0  16884.92     False        True             False
# 1   18  33.8         1   1725.55      True       False             False
# 2   28  33.0         3   4449.46      True       False             False
# 3   33  22.7         0  21984.47      True       False              True
# 4   32  28.9         0   3866.86      True       False              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False

# %%
from sklearn.preprocessing import StandardScaler
X = ds.drop("expenses", axis=1)
num_cols = X.select_dtypes(include="number").columns
scaler = StandardScaler()
X[num_cols] = scaler.fit_transform(X[num_cols])
X.head()
# Out:
#         age       bmi  children  sex_male  smoker_yes  region_northwest  \
# 0 -1.438764 -0.453646 -0.908614     False        True             False
# 1 -1.509965  0.514186 -0.078767      True       False             False
# 2 -0.797954  0.382954  1.580926      True       False             False
# 3 -0.441948 -1.306650 -0.908614      True       False              True
# 4 -0.513149 -0.289606 -0.908614      True       False              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False
